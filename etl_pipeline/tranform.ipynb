# %%
import pandas as pd

# %%
df = pd.read_csv('all_e.csv')
df.head()
# Out:
#     mag                                     place           time  \
# 0  1.00                  4 km E of Interlaken, CA  1717580367690
# 1  0.31               8 km NNW of The Geysers, CA  1717580248450
# 2  0.20        56 km NW of Indian Springs, Nevada  1717579915538
# 3  2.01  2 km WNW of Guadalupe Victoria, B.C., MX  1717579762140
# 4  1.01                7 km NW of The Geysers, CA  1717579474080
#
#          updated  tz                                                url  \
# 0  1717580465325 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  1717580345270 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  1717580015572 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  1717580125644 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  1717579570215 NaN  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                               detail  felt  cdi  mmi  ...  \
# ...

# %%
df.columns
# Out:
# Index(['mag', 'place', 'time', 'updated', 'tz', 'url', 'detail', 'felt', 'cdi',
#        'mmi', 'alert', 'status', 'tsunami', 'sig', 'net', 'code', 'ids',
#        'sources', 'types', 'nst', 'dmin', 'rms', 'gap', 'magType', 'type',
#        'title', 'lat', 'lon', 'depth', 'quake_id'],
#       dtype='object')

# %%
df = df.drop(columns=['tz', 'url', 'detail', 'mmi', 'sig', 'code', 'ids', 'sources', 'types', 'rms', 'dmin', 'title', 'updated', 'cdi'])
df.columns
# Out:
# Index(['mag', 'place', 'time', 'felt', 'alert', 'status', 'tsunami', 'net',
#        'nst', 'gap', 'magType', 'type', 'lat', 'lon', 'depth', 'quake_id'],
#       dtype='object')

# %%
df.head()
# Out:
#     mag                                     place           time  felt alert  \
# 0  1.00                  4 km E of Interlaken, CA  1717580367690   NaN   NaN
# 1  0.31               8 km NNW of The Geysers, CA  1717580248450   NaN   NaN
# 2  0.20        56 km NW of Indian Springs, Nevada  1717579915538   NaN   NaN
# 3  2.01  2 km WNW of Guadalupe Victoria, B.C., MX  1717579762140   NaN   NaN
# 4  1.01                7 km NW of The Geysers, CA  1717579474080   NaN   NaN
#
#       status  tsunami net   nst     gap magType        type        lat  \
# 0  automatic        0  nc   6.0  109.00      md  earthquake  36.961498
# 1  automatic        0  nc   9.0  103.00      md  earthquake  38.832832
# 2  automatic        0  nn  13.0   62.79      ml  earthquake  36.958500
# 3  automatic        0  ci  17.0  267.00      ml  earthquake  32.295833
# 4  automatic        0  nc  10.0   76.00      md  earthquake  38.816166
#
#           lon  depth    quake_id
# 0 -121.688164   5.85  nc75016582
# ...

# %%
df['time'] =  df.time.apply(lambda x: str(x)[:-3])
df['time'] = pd.to_datetime(df['time'],unit='s')

df.head()
# Out:
# /var/folders/ss/bxg8x4m10vzf_nkwfzk8vnd00000gp/T/ipykernel_4082/4229087180.py:2: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['time'] = pd.to_datetime(df['time'],unit='s')
#     mag                                     place                time  felt  \
# 0  1.00                  4 km E of Interlaken, CA 2024-06-05 09:39:27   NaN
# 1  0.31               8 km NNW of The Geysers, CA 2024-06-05 09:37:28   NaN
# 2  0.20        56 km NW of Indian Springs, Nevada 2024-06-05 09:31:55   NaN
# 3  2.01  2 km WNW of Guadalupe Victoria, B.C., MX 2024-06-05 09:29:22   NaN
# 4  1.01                7 km NW of The Geysers, CA 2024-06-05 09:24:34   NaN
#
#   alert     status  tsunami net   nst     gap magType        type        lat  \
# ...

# %%
df['felt'] = df['felt'].fillna(0)
df.head()
# Out:
#     mag                                     place                time  felt  \
# 0  1.00                  4 km E of Interlaken, CA 2024-06-05 09:39:27   0.0
# 1  0.31               8 km NNW of The Geysers, CA 2024-06-05 09:37:28   0.0
# 2  0.20        56 km NW of Indian Springs, Nevada 2024-06-05 09:31:55   0.0
# 3  2.01  2 km WNW of Guadalupe Victoria, B.C., MX 2024-06-05 09:29:22   0.0
# 4  1.01                7 km NW of The Geysers, CA 2024-06-05 09:24:34   0.0
#
#   alert     status  tsunami net   nst     gap magType        type        lat  \
# 0   NaN  automatic        0  nc   6.0  109.00      md  earthquake  36.961498
# 1   NaN  automatic        0  nc   9.0  103.00      md  earthquake  38.832832
# 2   NaN  automatic        0  nn  13.0   62.79      ml  earthquake  36.958500
# 3   NaN  automatic        0  ci  17.0  267.00      ml  earthquake  32.295833
# 4   NaN  automatic        0  nc  10.0   76.00      md  earthquake  38.816166
#
#           lon  depth    quake_id
# ...

# %%
df['alert'] = df['alert'].fillna('No alert')

df
# Out:
#        mag                                     place                time  \
# 0     1.00                  4 km E of Interlaken, CA 2024-06-05 09:39:27
# 1     0.31               8 km NNW of The Geysers, CA 2024-06-05 09:37:28
# 2     0.20        56 km NW of Indian Springs, Nevada 2024-06-05 09:31:55
# 3     2.01  2 km WNW of Guadalupe Victoria, B.C., MX 2024-06-05 09:29:22
# 4     1.01                7 km NW of The Geysers, CA 2024-06-05 09:24:34
# ...    ...                                       ...                 ...
# 9851  1.90             36 km S of False Pass, Alaska 2024-05-06 10:20:37
# 9852  0.75               2 km ENE of The Geysers, CA 2024-05-06 10:16:41
# 9853  2.60              78 km ENE of Chignik, Alaska 2024-05-06 10:16:20
# 9854  0.35                7 km NW of The Geysers, CA 2024-05-06 10:12:59
# 9855  1.07                20 km ESE of Point Sur, CA 2024-05-06 10:04:40
#
#       felt     alert     status  tsunami net   nst     gap magType  \
# ...

# %%
df = df[~df['place'].str.contains(' of ')]
df['place'].unique()
# Out:
# array(['Fiji region', 'Rat Islands, Aleutian Islands, Alaska',
#        'West Chile Rise', 'Easter Island region', 'western Xizang',
#        'Kermadec Islands, New Zealand', 'northern Mid-Atlantic Ridge',
#        'Kuril Islands', 'Kermadec Islands region',
#        'Pagan region, Northern Mariana Islands', 'Arctic Ocean',
#        'Maug Islands region, Northern Mariana Islands',
#        'Prince Edward Islands region', 'South Sandwich Islands region',
#        'Volcano Islands, Japan region',
#        'Galapagos Triple Junction region',
#        'Revilla Gigedo Islands region', 'central East Pacific Rise',
#        'Kepulauan Babar, Indonesia', 'Izu Islands, Japan region',
#        'southeast Indian Ridge', 'Banda Sea', 'North Indian Ocean',
#        'Mariana Islands region', 'Pacific-Antarctic Ridge',
#        'Balleny Islands region', 'Southwest Indian Ridge',
#        'Carlsberg Ridge', 'Bonin Islands, Japan region', 'Greenland Sea',
# ...
